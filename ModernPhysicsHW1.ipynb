# %%
import numpy as np 
import math
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib import style 
from scipy import signal

# %%
#定義重要需用函式、變數:
#a 有a,b兩個list a=... b=[3,-3]*10
def a_list(x):
    a = []
    for i in range(x):            

        if i %2 == 0:
            a+=[70+0.01*i/2]
        else:
            a+=[77-0.01*(i+1)/2]
    return a

#動畫架構
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)
# # animation function. This is called sequentially
# def animate(i):
#     sigs = [np.sin(2*np.pi*a*t+b*i) for a,b in zip(a,b)]
#     x = np.linspace(0, 5000, 2001)
#     y = sum(sigs[0:21])

#     line.set_data(x, y)
#     return (line,)

# ### call the animator. blit=True means only re-draw the parts that have changed.

# anim = animation.FuncAnimation(fig, animate, init_func=init,
#                                frames=100, interval=20, blit=True)

# # equivalent to rcParams['animation.html'] = 'html5'
# rc('animation', html='jshtml')
# rc

# HTML(anim.to_jshtml())

#變數
a = a_list(100)
b = [-0.3, 0.3]*10
t = np.linspace(0,1.0,2001)

# %%
# #zip用法
# # a = [ 70 ,84 ,71 ,85 ,72.1 ,87 ,73.5 ,84 ,73.8 ,88 ,75 ,83 ,74 ,82 ,72.1 ,83 ,70.5 ,84 ,73.8 ,88 ]
# a=[1,1,1,1]
# b = [-0.3, 0.3]*10
# sig = [a+b for a,b in zip(a,b)]
# print(sig)

# %%
#疊加1種不同頻率訊號
#動畫
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(1,1, figsize=(30,5))

ax.set_xlim(( 0, 5000)) #設x軸
ax.set_ylim((-2, 2)) #設y軸

#數據


line, = ax.plot([], [], lw=2) #??

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    sigs = [np.sin(2*np.pi*a*t+b*i) for a,b in zip(a,b)]
    x = np.linspace(0, 5000, 2001)
    y = sum(sigs[0:1])

    line.set_data(x, y)
    return (line,)

### call the animator. blit=True means only re-draw the parts that have changed.

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='jshtml')
rc

HTML(anim.to_jshtml())

# %%
#疊加2種不同頻率訊號
#動畫
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(1,1, figsize=(30,5))

ax.set_xlim(( 0, 5000)) #設x軸
ax.set_ylim((-3, 3)) #設y軸

#數據


line, = ax.plot([], [], lw=2) #??

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    sigs = [np.sin(2*np.pi*a*t+b*i) for a,b in zip(a,b)]
    x = np.linspace(0, 5000, 2001)
    y = sum(sigs[0:2])

    line.set_data(x, y)
    return (line,)

### call the animator. blit=True means only re-draw the parts that have changed.

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='jshtml')
rc

HTML(anim.to_jshtml())

# %%
#疊加5種不同頻率訊號
#動畫
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(1,1, figsize=(30,5))

ax.set_xlim(( 0, 5000)) #設x軸
ax.set_ylim((-7.5, 7.5)) #設y軸

#數據


line, = ax.plot([], [], lw=2) #??

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    sigs = [np.sin(2*np.pi*a*t+b*i) for a,b in zip(a,b)]
    x = np.linspace(0, 5000, 2001)
    y = sum(sigs[0:6])

    line.set_data(x, y)
    return (line,)

### call the animator. blit=True means only re-draw the parts that have changed.

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='jshtml')
rc

HTML(anim.to_jshtml())

# %%
#疊加10種不同頻率訊號
#動畫
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(1,1, figsize=(30,5))

ax.set_xlim(( 0, 5000)) #設x軸
ax.set_ylim((-12.5, 12.5)) #設y軸

#數據


line, = ax.plot([], [], lw=2) #??

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    sigs = [np.sin(2*np.pi*a*t+b*i) for a,b in zip(a,b)]
    x = np.linspace(0, 5000, 2001)
    y = sum(sigs[0:11])

    line.set_data(x, y)
    return (line,)

### call the animator. blit=True means only re-draw the parts that have changed.

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='jshtml')
rc

HTML(anim.to_jshtml())

# %%
#疊加20種不同頻率訊號
#動畫
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(1,1, figsize=(30,5))

ax.set_xlim(( 0, 5000)) #設x軸
ax.set_ylim((-25, 25)) #設y軸

#數據


line, = ax.plot([], [], lw=2) #??

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    sigs = [np.sin(2*np.pi*a*t+b*i) for a,b in zip(a,b)]
    x = np.linspace(0, 5000, 2001)
    y = sum(sigs[0:21])

    line.set_data(x, y)
    return (line,)

### call the animator. blit=True means only re-draw the parts that have changed.

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='jshtml')
rc

HTML(anim.to_jshtml())

# %%
#產生聲音 1個波 #以下皆待修
import pyaudio
import numpy as np

p = pyaudio.PyAudio()

volume = 0.5     # range [0.0, 1.0]
fs = 44100       # sampling rate, Hz, must be integer
duration = 3.0   # in seconds, may be float
f = 300.0        # sine frequency, Hz, may be float

# generate samples, note conversion to float32 array
samples = (np.sin(2*np.pi*np.arange(fs*duration)*70/fs)).astype(np.float32)


# for paFloat32 sample values must be in range [-1.0, 1.0]
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=fs,
                output=True)

# play. May repeat with different volume values (if done interactively) 
stream.write(volume*samples)

stream.stop_stream()
stream.close()

p.terminate()

# %%
#產生聲音 2個波
import pyaudio
import numpy as np

p = pyaudio.PyAudio()

volume = 0.5     # range [0.0, 1.0]
fs = 44100       # sampling rate, Hz, must be integer
duration = 3.0   # in seconds, may be float
f = 300.0        # sine frequency, Hz, may be float

# generate samples, note conversion to float32 array
samples = (np.sin(2*np.pi*np.arange(fs*duration)*70/fs+0.3)+np.sin(2*np.pi*np.arange(fs*duration)*77/fs+0.3)).astype(np.float32)


# for paFloat32 sample values must be in range [-1.0, 1.0]
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=fs,
                output=True)

# play. May repeat with different volume values (if done interactively) 
stream.write(volume*samples)

stream.stop_stream()
stream.close()

p.terminate()

# %%
# #產生聲音 3個波 成功!
# import pyaudio
# import numpy as np

# p = pyaudio.PyAudio()

# volume = 0.5     # range [0.0, 1.0]
# fs = 44100       # sampling rate, Hz, must be integer
# duration = 3.0   # in seconds, may be float
# f = 300.0        # sine frequency, Hz, may be float

# # generate samples, note conversion to float32 array
# # samples = (np.sin(2*np.pi*np.arange(fs*duration)*70/fs+0.3)+np.sin(2*np.pi*np.arange(fs*duration)*60/fs+0.3)+np.sin(2*np.pi*np.arange(fs*duration)*80/fs+0.3)).astype(np.float32)
# samples = (np.sin(2*np.pi*np.arange(fs*duration)*70+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*77-0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*70.1-0.3/fs)+ np.sin(2*np.pi*np.arange(fs*duration)*76.9+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.99-0.3/fs)).astype(np.float32)

# # for paFloat32 sample values must be in range [-1.0, 1.0]
# stream = p.open(format=pyaudio.paFloat32,
#                 channels=1,
#                 rate=fs,
#                 output=True)

# # play. May repeat with different volume values (if done interactively) 
# stream.write(volume*samples)

# stream.stop_stream()
# stream.close()

# p.terminate()

# %%
#產生聲音 5個波 
import pyaudio
import numpy as np

p = pyaudio.PyAudio()

volume = 0.5     # range [0.0, 1.0]
fs = 44100       # sampling rate, Hz, must be integer
duration = 3.0   # in seconds, may be float
f = 300.0        # sine frequency, Hz, may be float

# generate samples, note conversion to float32 array
# samples = (np.sin(2*np.pi*np.arange(fs*duration)*70/fs+0.3)+np.sin(2*np.pi*np.arange(fs*duration)*60/fs+0.3)+np.sin(2*np.pi*np.arange(fs*duration)*80/fs+0.3)).astype(np.float32)
samples = (np.sin(2*np.pi*np.arange(fs*duration)*70+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*77-0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*70.1-0.3/fs)+ np.sin(2*np.pi*np.arange(fs*duration)*76.9+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.99-0.3/fs)).astype(np.float32)

# for paFloat32 sample values must be in range [-1.0, 1.0]
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=fs,
                output=True)

# play. May repeat with different volume values (if done interactively) 
stream.write(volume*samples)

stream.stop_stream()
stream.close()

p.terminate()

# %%
#產生聲音 10個波 成功!
import pyaudio
import numpy as np

p = pyaudio.PyAudio()

volume = 0.5     # range [0.0, 1.0]
fs = 44100       # sampling rate, Hz, must be integer
duration = 3.0   # in seconds, may be float
f = 300.0        # sine frequency, Hz, may be float

# generate samples, note conversion to float32 array

samples = ((np.sin(2*np.pi*np.arange(fs*duration)*70+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*77-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.01+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.99-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.02+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.98-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.03+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.97-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.04+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.95-0.3/fs)
            ).astype(np.float32))

# for paFloat32 sample values must be in range [-1.0, 1.0]
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=fs,
                output=True)

# play. May repeat with different volume values (if done interactively) 
stream.write(volume*samples)

stream.stop_stream()
stream.close()

p.terminate()
scaled = np.int16(samples/np.max(np.abs(samples)) * 32767)
# write('waves10output.wav', 44100, scaled)

# %%
#產生聲音 20 個波 成功!
import pyaudio
import numpy as np

p = pyaudio.PyAudio()

volume = 0.5     # range [0.0, 1.0]
fs = 44100       # sampling rate, Hz, must be integer
duration = 3.0 # in seconds, may be float
f = 300.0        # sine frequency, Hz, may be float

# generate samples, note conversion to float32 array

samples = ((np.sin(2*np.pi*np.arange(fs*duration)*70+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*77-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.01+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.99-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.02+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.98-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.03+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.97-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.04+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.95-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.05+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.94-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.06+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.93-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.07+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.92-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.08+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.91-0.3/fs)
            +np.sin(2*np.pi*np.arange(fs*duration)*70.09+0.3/fs)+np.sin(2*np.pi*np.arange(fs*duration)*76.90-0.3/fs)
            ).astype(np.float32))

# for paFloat32 sample values must be in range [-1.0, 1.0]
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=fs,
                output=True)

# play. May repeat with different volume values (if done interactively) 
stream.write(volume*samples)

stream.stop_stream()
stream.close()

p.terminate()
